# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('uber.csv', index_col=0)

# %%
df.head()
# Out:
#                                     key  fare_amount          pickup_datetime  \
# 24238194    2015-05-07 19:52:06.0000003          7.5  2015-05-07 19:52:06 UTC
# 27835199    2009-07-17 20:04:56.0000002          7.7  2009-07-17 20:04:56 UTC
# 44984355   2009-08-24 21:45:00.00000061         12.9  2009-08-24 21:45:00 UTC
# 25894730    2009-06-26 08:22:21.0000001          5.3  2009-06-26 08:22:21 UTC
# 17610152  2014-08-28 17:47:00.000000188         16.0  2014-08-28 17:47:00 UTC
#
#           pickup_longitude  pickup_latitude  dropoff_longitude  \
# 24238194        -73.999817        40.738354         -73.999512
# 27835199        -73.994355        40.728225         -73.994710
# 44984355        -74.005043        40.740770         -73.962565
# 25894730        -73.976124        40.790844         -73.965316
# 17610152        -73.925023        40.744085         -73.973082
#
#           dropoff_latitude  passenger_count
# 24238194         40.723217                1
# 27835199         40.750325                1
# 44984355         40.772647                1
# 25894730         40.803349                3
# 17610152         40.761247                5

# %%
df.tail()
# Out:
#                                    key  fare_amount          pickup_datetime  \
# 42598914  2012-10-28 10:49:00.00000053          3.0  2012-10-28 10:49:00 UTC
# 16382965   2014-03-14 01:09:00.0000008          7.5  2014-03-14 01:09:00 UTC
# 27804658  2009-06-29 00:42:00.00000078         30.9  2009-06-29 00:42:00 UTC
# 20259894   2015-05-20 14:56:25.0000004         14.5  2015-05-20 14:56:25 UTC
# 11951496  2010-05-15 04:08:00.00000076         14.1  2010-05-15 04:08:00 UTC
#
#           pickup_longitude  pickup_latitude  dropoff_longitude  \
# 42598914        -73.987042        40.739367         -73.986525
# 16382965        -73.984722        40.736837         -74.006672
# 27804658        -73.986017        40.756487         -73.858957
# 20259894        -73.997124        40.725452         -73.983215
# 11951496        -73.984395        40.720077         -73.985508
#
#           dropoff_latitude  passenger_count
# 42598914         40.740297                1
# 16382965         40.739620                1
# 27804658         40.692588                2
# 20259894         40.695415                1
# 11951496         40.768793                1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 200000 entries, 24238194 to 11951496
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   key                200000 non-null  object
#  1   fare_amount        200000 non-null  float64
#  2   pickup_datetime    200000 non-null  object
#  3   pickup_longitude   200000 non-null  float64
#  4   pickup_latitude    200000 non-null  float64
#  5   dropoff_longitude  199999 non-null  float64
#  6   dropoff_latitude   199999 non-null  float64
#  7   passenger_count    200000 non-null  int64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 13.7+ MB

# %%
df.shape
# Out:
# (200000, 8)

# %%
df.describe()
# Out:
#          fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# count  200000.000000     200000.000000    200000.000000      199999.000000
# mean       11.359955        -72.527638        39.935885         -72.525292
# std         9.901776         11.437787         7.720539          13.117408
# min       -52.000000      -1340.648410       -74.015515       -3356.666300
# 25%         6.000000        -73.992065        40.734796         -73.991407
# 50%         8.500000        -73.981823        40.752592         -73.980093
# 75%        12.500000        -73.967154        40.767158         -73.963658
# max       499.000000         57.418457      1644.421482        1153.572603
#
#        dropoff_latitude  passenger_count
# count     199999.000000    200000.000000
# mean          39.923890         1.684535
# std            6.794829         1.385997
# min         -881.985513         0.000000
# 25%           40.733823         1.000000
# 50%           40.753042         1.000000
# 75%           40.768001         2.000000
# max          872.697628       208.000000

# %%
df.columns
# Out:
# Index(['key', 'fare_amount', 'pickup_datetime', 'pickup_longitude',
#        'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude',
#        'passenger_count'],
#       dtype='object')

# %%
df.nunique()
# Out:
# key                  200000
# fare_amount            1244
# pickup_datetime      196629
# pickup_longitude      71066
# pickup_latitude       83835
# dropoff_longitude     76894
# dropoff_latitude      90585
# passenger_count           8
# dtype: int64

# %%
df.sample(10)
# Out:
#                                    key  fare_amount          pickup_datetime  \
# 41262125  2012-12-27 21:52:00.00000073         10.5  2012-12-27 21:52:00 UTC
# 31358479   2012-03-15 01:42:32.0000004          4.5  2012-03-15 01:42:32 UTC
# 46106056   2013-11-27 07:33:54.0000003          9.0  2013-11-27 07:33:54 UTC
# 50175952   2013-12-09 10:40:09.0000002          7.0  2013-12-09 10:40:09 UTC
# 5695759    2009-04-05 02:35:51.0000005          9.4  2009-04-05 02:35:51 UTC
# 15179416   2012-10-09 22:08:41.0000001         10.5  2012-10-09 22:08:41 UTC
# 3038619    2011-05-10 16:53:10.0000001          5.7  2011-05-10 16:53:10 UTC
# 53051176   2011-01-18 06:47:18.0000004          8.1  2011-01-18 06:47:18 UTC
# 28187082   2009-11-09 01:50:05.0000001          6.9  2009-11-09 01:50:05 UTC
# 12556409  2010-06-21 11:40:00.00000048          7.3  2010-06-21 11:40:00 UTC
#
#           pickup_longitude  pickup_latitude  dropoff_longitude  \
# 41262125        -73.986282        40.748617         -73.977255
# 31358479        -73.990179        40.769864         -73.981650
# 46106056        -74.000735        40.730807         -73.994166
# 50175952        -73.986139        40.772433         -73.976230
# 5695759         -73.923331        40.761114         -73.918115
# 15179416        -74.002023        40.721002         -73.994260
# 3038619         -74.008000        40.723397         -74.004790
# 53051176          0.000000         0.000000           0.000000
# 28187082        -73.985727        40.747269         -73.992590
# 12556409          0.000000         0.000000           0.000000
#
#           dropoff_latitude  passenger_count
# 41262125         40.766157                1
# 31358479         40.763757                1
# 46106056         40.750465                1
# 50175952         40.791023                1
# 5695759          40.742418                1
# 15179416         40.690904                1
# 3038619          40.741792                1
# 53051176          0.000000                1
# 28187082         40.725872                1
# 12556409          0.000000                1

# %%
df.isnull().sum()
# Out:
# key                  0
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    1
# dropoff_latitude     1
# passenger_count      0
# dtype: int64

# %%
missing_percentage = df.isnull().mean() * 100
print(missing_percentage)
# Out:
# key                  0.0000
# fare_amount          0.0000
# pickup_datetime      0.0000
# pickup_longitude     0.0000
# pickup_latitude      0.0000
# dropoff_longitude    0.0005
# dropoff_latitude     0.0005
# passenger_count      0.0000
# dtype: float64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# key                  0
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    0
# dropoff_latitude     0
# passenger_count      0
# dtype: int64

# %%
def haversine(lat1, lon1, lat2, lon2):
    R = 6371  # Earth radius in kilometers
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = np.sin(dlat/2) ** 2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2) ** 2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))
    distance = R * c
    return distance

df['distance_km'] = haversine(df['pickup_latitude'], df['pickup_longitude'],
                              df['dropoff_latitude'], df['dropoff_longitude'])

# %%
df.isnull().sum()
# Out:
# key                  0
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    0
# dropoff_latitude     0
# passenger_count      0
# distance_km          0
# dtype: int64

# %%
df['pickup_datetime'] = pd.to_datetime(df['pickup_datetime'])

df['pickup_hour'] = df['pickup_datetime'].dt.hour

# %%
def categorize_time(hour):
    if 5 <= hour < 12:
        return 'morning'
    elif 12 <= hour < 17:
        return 'afternoon'
    elif 17 <= hour < 21:
        return 'evening'
    else:
        return 'night'

# %%
df['time_of_day'] = df['pickup_hour'].apply(categorize_time)
print(df['time_of_day'])
# Out:
# 24238194      evening
# 27835199      evening
# 44984355        night
# 25894730      morning
# 17610152      evening
#               ...
# 42598914      morning
# 16382965        night
# 27804658        night
# 20259894    afternoon
# 11951496        night
# Name: time_of_day, Length: 199999, dtype: object

# %%
df.describe()
# Out:
#          fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# count  199999.000000     199999.000000    199999.000000      199999.000000
# mean       11.359892        -72.527631        39.935881         -72.525292
# std         9.901760         11.437815         7.720558          13.117408
# min       -52.000000      -1340.648410       -74.015515       -3356.666300
# 25%         6.000000        -73.992065        40.734796         -73.991407
# 50%         8.500000        -73.981823        40.752592         -73.980093
# 75%        12.500000        -73.967154        40.767158         -73.963658
# max       499.000000         57.418457      1644.421482        1153.572603
#
#        dropoff_latitude  passenger_count    distance_km    pickup_hour
# count     199999.000000    199999.000000  199999.000000  199999.000000
# mean          39.923890         1.684543      20.855350      13.491387
# std            6.794829         1.385995     382.964642       6.515505
# min         -881.985513         0.000000       0.000000       0.000000
# 25%           40.733823         1.000000       1.215222       9.000000
# 50%           40.753042         1.000000       2.120992      14.000000
# 75%           40.768001         2.000000       3.875169      19.000000
# max          872.697628       208.000000   16409.239135      23.000000

# %%
df.describe()
# Out:
#          fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# count  199999.000000     199999.000000    199999.000000      199999.000000
# mean       11.359892        -72.527631        39.935881         -72.525292
# std         9.901760         11.437815         7.720558          13.117408
# min       -52.000000      -1340.648410       -74.015515       -3356.666300
# 25%         6.000000        -73.992065        40.734796         -73.991407
# 50%         8.500000        -73.981823        40.752592         -73.980093
# 75%        12.500000        -73.967154        40.767158         -73.963658
# max       499.000000         57.418457      1644.421482        1153.572603
#
#        dropoff_latitude  passenger_count    distance_km    pickup_hour
# count     199999.000000    199999.000000  199999.000000  199999.000000
# mean          39.923890         1.684543      20.855350      13.491387
# std            6.794829         1.385995     382.964642       6.515505
# min         -881.985513         0.000000       0.000000       0.000000
# 25%           40.733823         1.000000       1.215222       9.000000
# 50%           40.753042         1.000000       2.120992      14.000000
# 75%           40.768001         2.000000       3.875169      19.000000
# max          872.697628       208.000000   16409.239135      23.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 199999 entries, 24238194 to 11951496
# Data columns (total 11 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   key                199999 non-null  object
#  1   fare_amount        199999 non-null  float64
#  2   pickup_datetime    199999 non-null  datetime64[ns, UTC]
#  3   pickup_longitude   199999 non-null  float64
#  4   pickup_latitude    199999 non-null  float64
#  5   dropoff_longitude  199999 non-null  float64
#  6   dropoff_latitude   199999 non-null  float64
#  7   passenger_count    199999 non-null  int64
#  8   distance_km        199999 non-null  float64
#  9   pickup_hour        199999 non-null  int32
#  10  time_of_day        199999 non-null  object
# dtypes: datetime64[ns, UTC](1), float64(6), int32(1), int64(1), object(2)
# memory usage: 17.5+ MB

# %%
df.shape
# Out:
# (199999, 11)

# %%
pickup_longitude_outliers = df[(df['pickup_longitude'] < -180) | (df['pickup_longitude'] > 180)]
pickup_latitude_outliers = df[(df['pickup_latitude'] < -90) | (df['pickup_latitude'] > 90)]

try:
    df.drop(pickup_longitude_outliers.index, inplace=True)
except KeyError as e:
    print(f"KeyError for pickup_longitude_outliers: {e}")

try:
    df.drop(pickup_latitude_outliers.index, inplace=True)
except KeyError as e:
    print(f"KeyError for pickup_latitude_outliers: {e}")
# Out:
# KeyError for pickup_latitude_outliers: '[33249845] not found in axis'

# %%
# Filter out indices that are present in df
existing_longitude_outliers = pickup_longitude_outliers.index.intersection(df.index)
existing_latitude_outliers = pickup_latitude_outliers.index.intersection(df.index)

# Drop these existing outlier indices
df.drop(existing_longitude_outliers, inplace=True)
df.drop(existing_latitude_outliers, inplace=True)

# %%
df.describe()
# Out:
#          fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# count  199989.000000     199989.000000    199989.000000      199989.000000
# mean       11.359883        -72.501801        39.917945         -72.514942
# std         9.901824         10.449904         6.130381          10.517919
# min       -52.000000        -93.824668       -74.015515        -737.916665
# 25%         6.000000        -73.992065        40.734792         -73.991407
# 50%         8.500000        -73.981823        40.752591         -73.980092
# 75%        12.500000        -73.967154        40.767157         -73.963658
# max       499.000000         40.808425        48.018760          40.831932
#
#        dropoff_latitude  passenger_count    distance_km    pickup_hour
# count     199989.000000    199989.000000  199989.000000  199989.000000
# mean          39.924303         1.684558      20.634957      13.491532
# std            6.201159         1.386002     380.457537       6.515433
# min          -74.015750         0.000000       0.000000       0.000000
# 25%           40.733823         1.000000       1.215178       9.000000
# 50%           40.753042         1.000000       2.120856      14.000000
# 75%           40.768001         2.000000       3.874843      19.000000
# max          493.533332       208.000000   10321.507661      23.000000

# %%
dropoff_longitude_outliers = df[(df['dropoff_longitude'] < -180) | (df['dropoff_longitude'] > 180)]
dropoff_latitude_outliers = df[(df['dropoff_latitude'] < -90) | (df['dropoff_latitude'] > 90)]

# %%
try:
    df.drop(dropoff_longitude_outliers.index, inplace=True)
except KeyError as e:
    print(f"KeyError for dropoff_longitude_outliers: {e}")


try:
    df.drop(dropoff_latitude_outliers.index, inplace=True)
except KeyError as e:
    print(f"KeyError for dropoff_latitude_outliers: {e}")

# %%
df.describe()
# Out:
#          fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# count  199987.000000     199987.000000    199987.000000      199987.000000
# mean       11.359849        -72.501786        39.917937         -72.511608
# std         9.901868         10.449955         6.130412          10.412192
# min       -52.000000        -93.824668       -74.015515         -75.458979
# 25%         6.000000        -73.992064        40.734793         -73.991407
# 50%         8.500000        -73.981822        40.752592         -73.980092
# 75%        12.500000        -73.967154        40.767157         -73.963658
# max       499.000000         40.808425        48.018760          40.831932
#
#        dropoff_latitude  passenger_count    distance_km    pickup_hour
# count     199987.000000    199987.000000  199987.000000  199987.000000
# mean          39.922031         1.684544      20.560330      13.491562
# std            6.117669         1.385999     379.620738       6.515458
# min          -74.015750         0.000000       0.000000       0.000000
# 25%           40.733823         1.000000       1.215167       9.000000
# 50%           40.753042         1.000000       2.120825      14.000000
# 75%           40.768000         2.000000       3.874779      19.000000
# max           45.031598       208.000000    8782.898606      23.000000

# %%
fare_amount_outliers_min = df[df['fare_amount'] <= 5]
fare_amount_outliers_max = df[df['fare_amount'] > 500]

# %%
try:
    df.drop(fare_amount_outliers_min.index, inplace=True)
except KeyError as e:
    print(f"KeyError for fare_amount_outliers_min: {e}")
try:
    df.drop(fare_amount_outliers_max.index, inplace=True)
except KeyError as e:
    print(f"KeyError for fare_amount_outliers_max: {e}")

# %%
df.describe()
# Out:
#          fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# count  168901.000000     168901.000000    168901.000000      168901.000000
# mean       12.664186        -72.513453        39.923742         -72.535632
# std        10.246582         10.411226         6.117170          10.330174
# min         5.100000        -93.824668       -74.015515         -75.458979
# 25%         7.000000        -73.992292        40.733990         -73.991535
# 50%         9.300000        -73.981982        40.752158         -73.980090
# 75%        13.800000        -73.967402        40.766608         -73.963253
# max       499.000000         40.806012        48.018760          40.831932
#
#        dropoff_latitude  passenger_count    distance_km    pickup_hour
# count     168901.000000    168901.000000  168901.000000  168901.000000
# mean          39.934572         1.694768      20.228439      13.525290
# std            6.082658         1.406254     369.787080       6.531421
# min          -74.015750         0.000000       0.000000       0.000000
# 25%           40.732484         1.000000       1.575278       9.000000
# 50%           40.752603         1.000000       2.492311      14.000000
# 75%           40.767430         2.000000       4.368860      19.000000
# max           45.031598       208.000000    8776.106279      23.000000

# %%
distance_km_outliers_min = df[df['distance_km'] <= 0.1]
distance_km_outliers_max = df[df['distance_km'] > 80]

# %%
try:
    df.drop(distance_km_outliers_min.index, inplace=True)
except KeyError as e:
    print(f"KeyError for distance_km_outliers_min: {e}")

try:
    df.drop(distance_km_outliers_max.index, inplace=True)
except KeyError as e:
    print(f"KeyError for distance_km_outliers_max: {e}")

# %%
df.describe()
# Out:
#          fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# count  163543.000000     163543.000000    163543.000000      163543.000000
# mean       12.563705        -73.908925        40.686553         -73.907812
# std         9.812383          2.711674         2.654980           2.711781
# min         5.100000        -75.387785       -74.015515         -75.417737
# 25%         7.000000        -73.992525        40.735337         -73.991727
# 50%         9.300000        -73.982273        40.752736         -73.980570
# 75%        13.700000        -73.968708        40.767038         -73.965118
# max       230.000000         40.806012        42.478467          40.831932
#
#        dropoff_latitude  passenger_count    distance_km    pickup_hour
# count     163543.000000    163543.000000  163543.000000  163543.000000
# mean          40.686860         1.695328       3.808064      13.524296
# std            2.655329         1.315217       3.741876       6.529214
# min          -74.015750         0.000000       0.100431       0.000000
# 25%           40.734123         1.000000       1.644799       9.000000
# 50%           40.753280         1.000000       2.555477      14.000000
# 75%           40.767857         2.000000       4.437921      19.000000
# max           42.464187         6.000000      64.192811      23.000000

# %%
sns.scatterplot(x='distance_km', y='fare_amount', data=df)
# Out:
# <Axes: xlabel='distance_km', ylabel='fare_amount'>

# %%
sns.distplot(df['fare_amount'], bins = 10)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_10872\2012590803.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['fare_amount'], bins = 10)
# <Axes: xlabel='fare_amount', ylabel='Density'>

# %%
sns.relplot(x='distance_km', y='fare_amount', data=df, hue='time_of_day')

# %%
sns.boxplot(x=df['fare_amount'])
# Out:
# <Axes: xlabel='fare_amount'>

# %%
pip install scipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scipy in d:\anaconda3\lib\site-packages (1.13.1)
# Requirement already satisfied: numpy<2.3,>=1.22.4 in d:\anaconda3\lib\site-packages (from scipy) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
from scipy import stats

# %%
fare_amount_box, lambda_param = stats.boxcox(df['fare_amount'])

# %%
df['fare_amount_box'] = fare_amount_box

print(f"Optimal lambda parameter: {lambda_param}")
# Out:
# Optimal lambda parameter: -0.875701251990703

# %%
sns.relplot(x='distance_km', y='fare_amount', data=df, hue='time_of_day')

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

features = ['fare_amount', 'distance_km']
scaler = StandardScaler()

df[features] = scaler.fit_transform(df[features])

# %%
df.describe()
# Out:
#         fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# count  1.635430e+05     163543.000000    163543.000000      163543.000000
# mean  -1.514557e-16        -73.908925        40.686553         -73.907812
# std    1.000003e+00          2.711674         2.654980           2.711781
# min   -7.606437e-01        -75.387785       -74.015515         -75.417737
# 25%   -5.670102e-01        -73.992525        40.735337         -73.991727
# 50%   -3.326118e-01        -73.982273        40.752736         -73.980570
# 75%    1.158025e-01        -73.968708        40.767038         -73.965118
# max    2.215945e+01         40.806012        42.478467          40.831932
#
#        dropoff_latitude  passenger_count   distance_km    pickup_hour
# count     163543.000000    163543.000000  1.635430e+05  163543.000000
# mean          40.686860         1.695328  1.070096e-16      13.524296
# std            2.655329         1.315217  1.000003e+00       6.529214
# min          -74.015750         0.000000 -9.908519e-01       0.000000
# 25%           40.734123         1.000000 -5.781249e-01       9.000000
# 50%           40.753280         1.000000 -3.347495e-01      14.000000
# 75%           40.767857         2.000000  1.683270e-01      19.000000
# max           42.464187         6.000000  1.613761e+01      23.000000

# %%
scaler = MinMaxScaler()
df[features] = scaler.fit_transform(df[features])

# %%
df.describe()
# Out:
#          fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# count  163543.000000     163543.000000    163543.000000      163543.000000
# mean        0.033187        -73.908925        40.686553         -73.907812
# std         0.043630          2.711674         2.654980           2.711781
# min         0.000000        -75.387785       -74.015515         -75.417737
# 25%         0.008448        -73.992525        40.735337         -73.991727
# 50%         0.018675        -73.982273        40.752736         -73.980570
# 75%         0.038239        -73.968708        40.767038         -73.965118
# max         1.000000         40.806012        42.478467          40.831932
#
#        dropoff_latitude  passenger_count    distance_km    pickup_hour
# count     163543.000000    163543.000000  163543.000000  163543.000000
# mean          40.686860         1.695328       0.057848      13.524296
# std            2.655329         1.315217       0.058383       6.529214
# min          -74.015750         0.000000       0.000000       0.000000
# 25%           40.734123         1.000000       0.024096       9.000000
# 50%           40.753280         1.000000       0.038305      14.000000
# 75%           40.767857         2.000000       0.067676      19.000000
# max           42.464187         6.000000       1.000000      23.000000

# %%
numerical_df = df.select_dtypes(include=['number'])

numerical_df.info()
numerical_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 163543 entries, 24238194 to 11951496
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   fare_amount        163543 non-null  float64
#  1   pickup_longitude   163543 non-null  float64
#  2   pickup_latitude    163543 non-null  float64
#  3   dropoff_longitude  163543 non-null  float64
#  4   dropoff_latitude   163543 non-null  float64
#  5   passenger_count    163543 non-null  int64
#  6   distance_km        163543 non-null  float64
#  7   pickup_hour        163543 non-null  int32
# dtypes: float64(6), int32(1), int64(1)
# memory usage: 14.6 MB
#           fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 24238194     0.010671        -73.999817        40.738354         -73.999512
# 27835199     0.011561        -73.994355        40.728225         -73.994710
# 44984355     0.034682        -74.005043        40.740770         -73.962565
# 25894730     0.000889        -73.976124        40.790844         -73.965316
# 17610152     0.048466        -73.925023        40.744085         -73.973082
#
#           dropoff_latitude  passenger_count  distance_km  pickup_hour
# 24238194         40.723217                1     0.024697           19
# 27835199         40.750325                1     0.036778           20
# 44984355         40.772647                1     0.077013           21
# 25894730         40.803349                3     0.024359            8
# 17610152         40.761247                5     0.068261           17

# %%
correlation_matrix = numerical_df.corr()

correlation_matrix
# Out:
#                    fare_amount  pickup_longitude  pickup_latitude  \
# fare_amount           1.000000          0.013266        -0.009550
# pickup_longitude      0.013266          1.000000        -0.993963
# pickup_latitude      -0.009550         -0.993963         1.000000
# dropoff_longitude     0.011511          0.999865        -0.993949
# dropoff_latitude     -0.009318         -0.993927         0.999918
# passenger_count       0.009351          0.010877        -0.010940
# distance_km           0.889348          0.005110        -0.002131
# pickup_hour          -0.026876          0.001093        -0.000354
#
#                    dropoff_longitude  dropoff_latitude  passenger_count  \
# fare_amount                 0.011511         -0.009318         0.009351
# pickup_longitude            0.999865         -0.993927         0.010877
# pickup_latitude            -0.993949          0.999918        -0.010940
# dropoff_longitude           1.000000         -0.993911         0.010869
# dropoff_latitude           -0.993911          1.000000        -0.010891
# passenger_count             0.010869         -0.010891         1.000000
# distance_km                 0.004048         -0.001362         0.003637
# pickup_hour                 0.000042         -0.000388         0.015354
#
#                    distance_km  pickup_hour
# fare_amount           0.889348    -0.026876
# pickup_longitude      0.005110     0.001093
# pickup_latitude      -0.002131    -0.000354
# dropoff_longitude     0.004048     0.000042
# dropoff_latitude     -0.001362    -0.000388
# passenger_count       0.003637     0.015354
# distance_km           1.000000    -0.040726
# pickup_hour          -0.040726     1.000000

# %%
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
# Out:
# <Axes: >

# %%
sns.pairplot(df[['fare_amount', 'distance_km', 'pickup_hour']])

# %%
from sklearn.model_selection import train_test_split

# %%
X = df[['distance_km']]
y = df['fare_amount']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=100)

# %%
print(f"Training set size: {X_train.shape[0]}")
print(f"Test set size: {X_test.shape[0]}")
# Out:
# Training set size: 114480
# Test set size: 49063

# %%
from sklearn.ensemble import GradientBoostingRegressor


gb_model = GradientBoostingRegressor(n_estimators=65, learning_rate=0.1, max_depth=3, random_state=110)

gb_model.fit(X_train, y_train)

#Testing
y_pred = gb_model.predict(X_test)


#Evaluate the Model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')
# Out:
# Mean Squared Error: 0.0003636415022014452
# R-squared: 0.8123033617450064
